# %%
import requests
import json

# Cole sua chave de API e endpoint do Azure OpenAI aqui
api_key = "" #chave retirada por segurança
endpoint = "" #end point retirado por segurança

headers = {
    "Content-Type": "application/json",
    "api-key": api_key
}

data = {
    "messages": [
        {"role": "system", "content": "Você é um tradutor profissional do inglês para o português brasileiro."},
        {"role": "user", "content": """The Road to Independence: The Story of the USA

In the 1700s, the land we now know as the United States was not a single country. It was thirteen separate colonies ruled by Great Britain. People had come from Europe to these colonies seeking religious freedom and new opportunities. For a long time, the relationship between the colonists and Great Britain was mostly peaceful. However, things began to change.

Growing Tensions

After a long war with France, Great Britain was in a lot of debt. To raise money, the British government started to impose new taxes on the American colonies. One famous tax was on tea. The colonists were very angry about these taxes. They felt it was unfair because they had no representatives in the British Parliament to speak for them. This idea was famously summarized by the phrase, 'No taxation without representation.'
The British government also sent soldiers to the colonies to enforce its laws. The colonists were forced to provide housing and food for these soldiers. This created more tension and frustration. Protests became common, and some, like the Boston Tea Party in 1773 where colonists dumped tea into the harbor, were very famous.

The Declaration of Independence

Leaders from the thirteen colonies decided to meet and discuss the problems with Great Britain. This group was called the Continental Congress. At first, they tried to find a peaceful solution. But as the situation worsened, the idea of becoming a separate country grew stronger.
In 1776, the Continental Congress made a historic decision. They asked Thomas Jefferson to write a document that would officially announce their separation from Great Britain. This document is the Declaration of Independence. On July 4, 1776, the leaders approved it. The Declaration stated that all people have certain rights, including 'Life, Liberty and the pursuit of Happiness,' and that the colonies were now 'free and independent states.'

The Revolutionary War

Declaring independence was one thing, but winning it was another. A long and difficult war, known as the Revolutionary War, began between the colonists and the powerful British army. George Washington was chosen to be the commander-in-chief of the Continental Army.
The American soldiers were not as well-trained or equipped as the British soldiers. They faced many hardships, including cold winters and a lack of supplies. However, they were fighting for their freedom and their homes, which gave them a strong motivation. A key moment in the war was the Battle of Saratoga in 1777. The American victory convinced France to help the colonists, which was a very important turning point.

A New Nation

The war finally ended in 1781 with the American victory at the Battle of Yorktown. Two years later, in 1783, the Treaty of Paris was signed, and Great Britain officially recognized the independence of the United States of America.
After winning the war, the new country had to create its own government. The leaders wrote the Constitution, a document that established the rules and structure of the new government and guaranteed the rights of its citizens. George Washington, the hero of the war, became the first President of the United States. The birth of the USA showed the world that a colony could successfully fight for its freedom and create its own democratic government."""
        }
    ],
    "max_tokens": 1500,
    "temperature": 0
}

response = requests.post(endpoint, headers=headers, json=data)
response.raise_for_status()  # Para lançar erro se a chamada falhar

translated_text = response.json()['choices'][0]['message']['content']
print(translated_text)
# Out:
# **O Caminho para a Independência: A História dos EUA**
#
# No século XVIII, a terra que hoje conhecemos como os Estados Unidos não era um único país. Tratava-se de treze colônias separadas, governadas pela Grã-Bretanha. Muitas pessoas haviam vindo da Europa para essas colônias em busca de liberdade religiosa e novas oportunidades. Durante muito tempo, a relação entre os colonos e a Grã-Bretanha foi, em grande parte, pacífica. No entanto, as coisas começaram a mudar.
#
# **Crescentes Tensões**
#
# ...
